# %%
import numpy as np
import pandas as pd
import matplotlib

import matplotlib.pyplot as plt

# %%
predLoc = "/home/ubuntu/data/moons/preds/preds.csv"
actLoc = "/home/ubuntu/data/moons/actuals/actuals.csv"

# %%
preds = pd.read_csv(predLoc)
actuals = pd.read_csv(actLoc)

# %%
colors = ['red','blue']

# %%
actuals.head()
# Out:
#           x         y  class
# 0 -1.960320  0.274402      0
# 1 -1.569716  0.787953      0
# 2 -1.545093  0.793283      0
# 3 -1.490508  0.208709      0
# 4 -1.475065  0.005031      0

# %%
# Plot actuals
fig = plt.figure(figsize=(6,6))
plt.scatter(actuals["x"], actuals["y"], c=actuals["class"], cmap=matplotlib.colors.ListedColormap(colors))

# %%
# Plot predictions
fig = plt.figure(figsize=(6,6))
plt.scatter(df["x"], df["y"], c=df["prediction"], cmap=matplotlib.colors.ListedColormap(colors))
